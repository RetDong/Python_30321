# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(0,5,1)

y1=x+1
y2=x+2
y3=x+3
y4=x+4

plt.subplot(1,2,1)

plt.plot(x,y1,'xr--')
plt.plot(x,y2,'ob--')

plt.subplot(1,2,2)

plt.plot(x,y3,'sy--')
plt.plot(x,y4,'g^--')
