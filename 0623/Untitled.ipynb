# %%
import matplotlib.pyplot as plt
a = ([10, 20, 30, 40])
b = (['kor','eng','math','info'])
plt.plot(a, b, 'g--')
plt.ylabel('some numbers')
# Out:
# Text(0, 0.5, 'some numbers')

# %%
import matplotlib.pyplot as plt
a = ([10, -20, 30, 40])
b = ([30, -10, 20, 60])
c = (['kor','eng','math','info'])
plt.bar(c, a, color='red')
plt.ylabel('jumsu')
plt.xlabel('subject')
plt.title('Score')
plt.legend('value')
